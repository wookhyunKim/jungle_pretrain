# %%
import requests # requests 라이브러리 설치 필요

r = requests.get('http://openapi.seoul.go.kr:8088/6d4d776b466c656533356a4b4b5872/json/RealtimeCityAir/1/99')
rjson = r.json()

print(rjson)
print(rjson['RealtimeCityAir']['row'][0]['NO2']) # 중구의 NO2 값
# Out:
# {'RealtimeCityAir': {'list_total_count': 25, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'MSRDT': '202405091600', 'MSRRGN_NM': '도심권', 'MSRSTE_NM': '중구', 'PM10': 30.0, 'PM25': 17.0, 'O3': 0.072, 'NO2': 0.013, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 84.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '도심권', 'MSRSTE_NM': '종로구', 'PM10': 36.0, 'PM25': 19.0, 'O3': 0.075, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 87.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '도심권', 'MSRSTE_NM': '용산구', 'PM10': 43.0, 'PM25': 23.0, 'O3': 0.068, 'NO2': 0.013, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 81.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서북권', 'MSRSTE_NM': '은평구', 'PM10': 39.0, 'PM25': 13.0, 'O3': 0.058, 'NO2': 0.01, 'CO': 0.4, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 73.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서북권', 'MSRSTE_NM': '서대문구', 'PM10': 47.0, 'PM25': 18.0, 'O3': 0.079, 'NO2': 0.013, 'CO': 0.3, 'SO2': 0.002, 'IDEX_NM': '보통', 'IDEX_MVL': 91.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서북권', 'MSRSTE_NM': '마포구', 'PM10': 31.0, 'PM25': 17.0, 'O3': 0.083, 'NO2': 0.012, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 94.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '광진구', 'PM10': 44.0, 'PM25': 18.0, 'O3': 0.088, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.004, 'IDEX_NM': '보통', 'IDEX_MVL': 97.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '성동구', 'PM10': 33.0, 'PM25': 17.0, 'O3': 0.076, 'NO2': 0.013, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 87.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '중랑구', 'PM10': 27.0, 'PM25': 18.0, 'O3': 0.068, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 81.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '동대문구', 'PM10': 36.0, 'PM25': 18.0, 'O3': 0.077, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 88.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '성북구', 'PM10': 41.0, 'PM25': 15.0, 'O3': 0.07, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.002, 'IDEX_NM': '보통', 'IDEX_MVL': 83.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '도봉구', 'PM10': 44.0, 'PM25': 14.0, 'O3': 0.07, 'NO2': 0.009, 'CO': 0.4, 'SO2': 0.004, 'IDEX_NM': '보통', 'IDEX_MVL': 83.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '강북구', 'PM10': 33.0, 'PM25': 17.0, 'O3': 0.078, 'NO2': 0.009, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 89.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '동북권', 'MSRSTE_NM': '노원구', 'PM10': 35.0, 'PM25': 18.0, 'O3': 0.078, 'NO2': 0.012, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 90.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_NM': '강서구', 'PM10': 32.0, 'PM25': 13.0, 'O3': 0.069, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 82.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_NM': '구로구', 'PM10': 37.0, 'PM25': 17.0, 'O3': 0.078, 'NO2': 0.007, 'CO': 0.2, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 90.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_NM': '영등포구', 'PM10': 35.0, 'PM25': 17.0, 'O3': 0.077, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 88.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_NM': '동작구', 'PM10': 31.0, 'PM25': 16.0, 'O3': 0.081, 'NO2': 0.011, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 92.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_NM': '관악구', 'PM10': 32.0, 'PM25': 17.0, 'O3': 0.079, 'NO2': 0.01, 'CO': 0.3, 'SO2': 0.003, 'IDEX_NM': '보통', 'IDEX_MVL': 90.0, 'ARPLT_MAIN': 'O3'}, {'MSRDT': '202405091600', 'MSRRGN_NM': '서남권', 'MSRSTE_ ...
# 0.013

# %%
gus = rjson['RealtimeCityAir']['row']

for gu in gus:
    print(gu['MSRSTE_NM'], gu['IDEX_MVL'])
# Out:
# 중구 84.0
# 종로구 87.0
# 용산구 81.0
# 은평구 73.0
# 서대문구 91.0
# 마포구 94.0
# 광진구 97.0
# 성동구 87.0
# 중랑구 81.0
# 동대문구 88.0
# 성북구 83.0
# 도봉구 83.0
# 강북구 89.0
# 노원구 90.0
# 강서구 82.0
# 구로구 90.0
# 영등포구 88.0
# 동작구 92.0
# 관악구 90.0
# 금천구 86.0
# 양천구 89.0
# 강남구 91.0
# 서초구 78.0
# 송파구 92.0
# 강동구 116.0

# %%
#IDEX_MVL 값이 60 미만인 구의 이름과 값 프린트하기
for gu in gus:
    if gu["IDEX_MVL"] < 90:
        print(gu['MSRSTE_NM'], gu['IDEX_MVL'])
# Out:
# 중구 84.0
# 종로구 87.0
# 용산구 81.0
# 은평구 73.0
# 성동구 87.0
# 중랑구 81.0
# 동대문구 88.0
# 성북구 83.0
# 도봉구 83.0
# 강북구 89.0
# 강서구 82.0
# 영등포구 88.0
# 금천구 86.0
# 양천구 89.0
# 서초구 78.0

# %%
import requests
from bs4 import BeautifulSoup

# 타겟 URL을 읽어서 HTML를 받아오고,
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}
data = requests.get('https://movie.daum.net/ranking/boxoffice/yearly', headers=headers)

# HTML을 BeautifulSoup이라는 라이브러리를 활용해 검색하기 용이한 상태로 만듦
# soup이라는 변수에 "파싱 용이해진 html"이 담긴 상태가 됨
# 이제 코딩을 통해 필요한 부분을 추출하면 된다.
soup = BeautifulSoup(data.text, 'html.parser')
print(soup)  # HTML을 받아온 것을 확인할 수 있다.


#############################
# (입맛에 맞게 코딩)
#############################
# Out:
# <!DOCTYPE html>
#
# <html class="os_mac" lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="다음연예" property="og:author">
# <meta content="다음연예" property="og:site_name">
# <meta content="최신 뉴스" property="og:title"/>
# <meta content="//t1.daumcdn.net/media/img-media/mobile/meta/enter.png" property="og:image"/>
# <meta content="다음연예" property="og:description"/>
# <meta content="https://entertain.daum.net/news/movie" property="og:url"/>
# <title>최신 뉴스 | 다음연예</title>
# <link href="//i1.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <script src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>
#     var ENV = {
#         Profile: {
#             isProduction: 'true' || false,
#             isSandbox: '' || false,
#             isCbt: '' || false,
#         }
#     }
# </script>
# <link href="//t1.daumcdn.net/media/kraken/entertain/a8870fe/commonCSSBundle.merged.css" rel="stylesheet" type="text/css">
# <style>
#     .owl-item{float:left}
# </style>
# <script src="//t1.daumcdn.net/media/kraken/entertain/a8870fe/common.merged.js"></script>
# <script src="//t1.daumcdn.net/media/kraken/entertain/a8870fe/NewsMainComponent.merged.js"></script>
# </link></meta></meta></head>
# <body>
# <div id="kakaoIndex">
# <a href="#kakaoBody">본문 바로가기</a>
# <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="entertain_type1" id="kakaoWrap">
# <div id="wrapMinidaum"></div>
# <script type="text/javascript">
# 	var minidaum_options = {
# 		// background 타입 지정 관련 옵션. default: white.
# 		bgType: "white", // white, dark, custom(no background)
# 		// logout 시 return url 변경 여부 flag : default: false - 다음탑으로 이동
# 		enableLogoutRetun: true, // false - 다음탑으로 이동, true - 현재페이지 혹은 returnUrl 값으로 이동
# 		returnUrl: window.location.href, // default='' , 현재페이지 = window.location.href
# 		// 실시간 이슈 사용 여부, default: false
# 		disableHotissue: false, // false일 경우 사용, true일 경우 미사용
# 		// 로고 사용 여부, default: false
# 		disableLogo: true, // false일 경우 사용, true일 경우 미사용
# 		// 티아라 사용 여부, default: false
# 		disableTracker: true, // false일 경우 사용, true일 경우 미사용
# 		// 플래시에 의한 레이어 가림 현상 방지 사용 여부, default: false
# 		enableShield: false // false일 경우 미사용, true일 경우 사용
# 	}
# </script>
# <script src="https://go.daum.net/minidaum_pc.daum"></script>
# <div id="kakaoHead" role="banner">
# <div class="kakaohead_top">
# <h1 class="tit_daum">
# <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
# <img alt="Daum" class="thumb_g" height="18" src="//t1.daumcdn.net/media/entertain/entertain2020/rtn/logo_daum_210224.png" width="44"/>
# </a>
# <a data-tiara-layer="gnb service enter" href="https://entertain.daum.net" id="kakaoServiceLogo"><span class="ir_wa">연예</span></a>
# </h1>
# <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServices">
# <li><a class="link_services" data-tiara-layer="gnb service news" href="https://news.daum.net">뉴스</a></li>
# <li><a class="link_services" data-tiara-layer="gnb service sports" href="https://sports.daum.net">스포츠</a></li>
# </ul>
# </div>
# <div id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">연예 메인메뉴</h2>
# <ul class="gnb_enter">
# <li>
# <a class="link_gnb link_gnb1" data-tiara-layer="gnb tab home" href="/">
# <span class="ir_wa">홈</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# <li>
# <a class="link_gnb link_gnb2" data-tiara-layer="gnb tab ranking" href="/ranking/keyword">
# <span class="ir_wa">랭킹</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# <li class="on">
# <a class="link_gnb link_gnb3" data-tiara-layer="gnb tab news" href="/news">
# <span class="ir_wa">뉴스</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# <li>
# <a class="link_gnb link_gnb5" data-tiara-layer="gnb tab tv" href="/tv">
# <span class="ir_wa">TV</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# <li>
# <a class="link_gnb link_gnb7" data-tiara-layer="gnb tab photo" href="/photo">
# <span class="ir_wa">포토</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# <li>
# <a class="link_gnb link_gnb8" data-tiara-layer="gnb tab poll" href="/poll">
# <span class="ir_wa">투표</span>
# <span class="bar_gnb"><span class="inner_bar"></span></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- // kakaoHead -->
# <script src="//t1.daumcdn.net/media/kraken/entertain/a8870fe/MouseOverComponent.merged.js"></script>
# <div class="cont_news no_ad" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">최신 뉴스</h2>
# <div id="cMain">
# <div data-date="" data-page="1" id="mArticle">
# <div class="head_enter">
# <div class="tab_enter">
# <a class="link_tab on" data-tiara-layer="tab new" href="/news">최신</a>
# <a class="link_tab" data-tiara-layer="tab series" href="/news/series">연재</a>
# </div>
# <div class="tab_enter2">
# <a class="link_tab" data-tiara-layer="tab_catagory all" href="/news">전체</a>
# <a class="link_tab" data-tiara-layer="tab_catagory star" href="/news/star">스타</a>
# <a class="link_tab" data-tiara-layer="tab_catagory drama" href="/news/drama">드라마</a>
# <a class="link_tab" data-tiara-layer="tab_catagory variety" href="/news/variety">예능</a>
# <a class="link_tab" data-tiara-layer="tab_catagory music" href="/news/music">뮤직</a>
# <a class="link_tab on" data-tiara-layer="tab_catagory movie" href="/news/movie">영화</a>
# <a class="link_tab" data-tiara-layer="tab_catagory abroad" href="/news/abroad">해외</a>
# </div>
# </div>
# <div class="box_g box_news box_allnews">
# <h3 class="screen_out">최신뉴스</h3>
# <h4 class="screen_out"></h4>
# <ul class="list_news" data-tiara-layer="recentnews news_list">
# </ul>
# </div>
# <div class="paging_enter">
# </div>
# <div class="date_nav">
# </div>
# </div>
# <div data-tiara-layer="right" id="mAside" role="complementary">
# <div class="aside_g aside_ad">
# <h3 class="screen_out">광고</h3>
# <ins class="kakao_ad_area" data-ad-frame-id="adWing" data-ad-frame-name="adWing" data-ad-height="250" data-ad-type="D" data-ad-unit="08E76" data-ad-width="250" style="display:block">
# </ins>
# </div>
# <div class="aside_g aside_phototv">
# <h3 class="tit_enter">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_multimedia" data-tiara-layer="photo_tv">
# <li>
# <div class="item_multimedia">
# <a class="wrap_thumb" data-tiara-ordnum="1" href="https://gallery.v.daum.net/p/viewer/247/XKKR9yVZee">
# <div class="thumb_img"><img alt="한혜진, 간절함 없는 엉망진창 셀카..막 찍어도 꽃미모" class="thumb_g" src="https://img1.daumcdn.net/thumb/S144x100ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202405%2F09%2FSPORTSSEOUL%2F20240509130049784kraf.jpg&amp;scode=media"/></div>
# <span class="ico_enter ico_photo">포토뷰</span>
# </a>
# <div class="cont_thumb">
# <strong class="tit_item"><a class="link_txt" data-tiara-layer="right photo_tv photo" data-tiara-ordnum="1" href="https://gallery.v.daum.net/p/viewer/247/XKKR9yVZee">한혜진, 간절함 없는 엉망진창 셀카..막 찍어도 꽃미모</a></strong>
# </div>
# </div>
# </li>
# <li>
# <div class="item_multimedia">
# <a class="wrap_thumb" data-tiara-ordnum="2" href="https://gallery.v.daum.net/p/viewer/250/t19qI4wMRE">
# <div class="thumb_img"><img alt="엔하이픈 선우 ‘월드투어 마치고 왔어요~’" class="thumb_g" src="https://img1.daumcdn.net/thumb/S144x100ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202405%2F09%2Fnewsen%2F20240509160500118lmxy.jpg&amp;scode=media"/></div>
# <span class="ico_enter ico_photo">포토뷰</span>
# </a>
# <div class="cont_thumb">
# <strong class="tit_item"><a class="link_txt" data-tiara-layer="right photo_tv photo" data-tiara-ordnum="2" href="https://gallery.v.daum.net/p/viewer/250/t19qI4wMRE">엔하이픈 선우 ‘월드투어 마치고 왔어요~’</a></strong>
# </div>
# </div>
# </li>
# <li>
# <div class="item_multimedia">
# <a class="wrap_thumb" data-tiara-ordnum="3" href="https://entertain.daum.net/tv/5901525/video/446574538">
# <div class="thumb_img"><img alt="부부 싸움이 의심될 정도로 너무 COOL한 ✨31년 차 부부✨ TV CHOSUN 240508 방송" class="thumb_g" src="https://img1.daumcdn.net/thumb/S144x100ht.u/?fname=https%3A%2F%2Fthumb.kakaocdn.net%2Fdna%2Fkamp%2Fsource%2Frv1qff5o0cr6ycy01dsz7zdx3%2Fthumbs%2Fthumb.jpg%3Fcredential%3DTuMuFGKUIcirOSjFzOpncbomGFEIdZWK%26expires%3D33272085640%26signature%3DBDf9Ak5piFpt18Txu7dzJ1Qjv3o%253D&amp;scode=media"/></div>
# <span class="info_play"><span class="screen_out">재생시간</span>02:44</span>
# </a>
# <div class="cont_thumb">
# <strong class="tit_item"><a class="link_txt" data-tiara-layer="right photo_tv photo" data-tiara-ordnum="3" href="https://entertain.daum.net/tv/5901525/video/446574538">부부 싸움이 의심될 정도로 너무 COOL한 ✨31년 차 부부✨ TV CHOSUN 240508 방송</a></strong>
# </div>
# </div>
# </li>
# <li>
# <div class="item_multimedia">
# <a class="wrap_thumb" data-tiara-ordnum="4" href="https://entertain.daum.net/tv/5852822/video/446575476">
# <div class="thumb_img"><img alt=" 모두가 감탄한 오늘의 주인공 등장! 제천 설현이라고? MBN 240508 방송" class="thumb_g" src="https://img1.daumcdn.net/thumb/S144x100ht.u/?fname=https%3A%2F%2Fthumb.kakaocdn.net%2Fdna%2Fkamp%2Fsource%2Frv9etrbs695akvq7bvzxi8wen%2Fthumbs%2Fthumb.jpg%3Fcredential%3DTuMuFGKUIcirOSjFzOpncbomGFEIdZWK%26expires%3D33272089106%26signature%3DbNAOhasWm6QK1NHmgpxFTJWzAAo%253D%26ts%3D1715180306&amp;scode=media"/></div>
# <span class="info_play"><span class="screen_out">재생시간</span>04:15</span>
# </a>
# <div class="cont_thumb">
# <strong class="tit_item"><a class="link_txt" data-tiara-layer="right photo_tv photo" data-tiara-ordnum="4" href="https://entertain.daum.net/tv/5852822/video/446575476"> 모두가 감탄한 오늘의 주인공 등장! 제천 설현이라고? MBN 240508 방송</a></strong>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_poll">
# <h3 class="tit_enter">투표</h3>
# <div class="cont_aside">
# <span class="wrap_thumb">
# <img alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S296x150ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fsection%2Foc%2F5244eb06747e45dfafd47b724c16cbdc&amp;scode=media"/>
# </span>
# <a class="cont_thumb" data-tiara-layer="poll" href="/poll/27916">
# <strong class="tit_thumb">
# <span class="inner_tit">
# <span class="ico_enter ico_question">Q</span>백상 대상 '무빙'·'서울의 봄' 수상 결과 공감하시나요?<span class="btn_poll">투표하기</span>
# </span>
# </strong>
# </a>
# </div>
# </div>
# <div class="aside_g aside_shopping">
# <h3 class="screen_out">광고</h3>
# <div id="daum-sfocus-root">
# <ins class="kakao_ad_area" data-ad-frame-id="adWing" data-ad-frame-name="adWing" data-ad-height="250" data-ad-type="D" data-ad-unit="DAN-IUpi96pXnc0yJVZe" data-ad-width="250" style="display:block">
# </ins>
# </div>
# </div>
# </div>
# </div>
# <div class="wrap_post">
# <div class="box_post">
# <a class="btn_close" href="#none"><span class="ico_enter">레이어 닫기</span></a>
# <iframe height="600px" name="postView" style="border:0" width="560px"></iframe>
# </div>
# </div>
# <div class="cl_b"></div>
# </div>
# <hr class="hide"/>
# <div class="footer_comm" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot" data-tiara-layer="footer">
# <div class="direct_link" data-tiara-layer="direct">
# <h2 class="screen_out">바로가기</h2>
# <div class="direct_bundle">
# <div class="item_bundle">
# <a class="link_txt" data-tiara-layer="footer direct ranking" href="/ranking/keyword">TOP키워드</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" data-tiara-layer="footer direct news" href="/news">최신뉴스</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" data-tiara-layer="footer direct series" href="/news/series">연재</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt" data-tiara-layer="footer direct gallery" href="/tv">TV</a>
# </div>
# </div>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link">
# <a class="link_info" data-tiara-layer="footer info_daumnews" href="https://news.daum.net/info/intro">다음뉴스 소개</a>
# <a class="link_info" data-tiara-layer="footer notice" href="https://magazine.daum.net/daumenter_notice">공지사항</a>
# <a class="link_info" data-tiara-layer="footer bbsrule" href="https://news.daum.net/info/bbsrule">게시물 운영원칙</a>
# <a class="link_info" data-tiara-layer="footer policy" href="http://policy.daum.net/info/info">서비스 약관/정책</a>
# <a class="link_info" data-tiara-layer="footer harmony" href="https://with.kakao.com/media">뉴스제휴</a>
# <a class="link_info" data-tiara-layer="footer adinfo" href="https://business.kakao.com/">비즈니스</a>
# <a class="link_info" data-tiara-layer="footer redbell" href="https://cs.daum.net/redbell/top.html">권리침해신고</a>
# <a class="link_info" data-tiara-layer="footer consumer" href="http://cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link">
# <a class="link_info" data-tiara-layer="footer newscenter" href="https://news.daum.net/info/newscenter24">24시간 뉴스센터</a>
# <a class="link_info" data-tiara-layer="footer edit" href="https://news.daum.net/info/edit">서비스원칙</a>
# <span class="link_info">기사배열책임자 : 황유지</span>
# <span class="link_info">청소년보호책임자 : 손성희</span>
# </div>
# <div class="info_copyright">
# <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
# <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div> <!-- // kakaoFoot -->
# <script async="" src="//t1.daumcdn.net/kas/static/ba.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/media/kraken/entertain/a8870fe/MoreButtonComponent.merged.js"></script>
# </div>
# </body>
# </html>
